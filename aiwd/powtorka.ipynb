# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'col':[1,2,3,4],
              'col2': pd.date_range('2015-01-01', periods=4)
              })

# %%
df.loc[4] = [4, '2012-01-01']

# %%
df_new = pd.DataFrame({'col':[5,6,7,8],
              'col2': pd.date_range('2015-01-01', periods=4)
              })

# %%
pd.concat([df, df_new], ignore_index=True)
# Out:
#    col                 col2
# 0    1  2015-01-01 00:00:00
# 1    2  2015-01-02 00:00:00
# 2    3  2015-01-03 00:00:00
# 3    4  2015-01-04 00:00:00
# 4    4           2012-01-01
# 5    5  2015-01-01 00:00:00
# 6    6  2015-01-02 00:00:00
# 7    7  2015-01-03 00:00:00
# 8    8  2015-01-04 00:00:00

# %%
['item_' + str(i) for i in range(0, df.shape[0])]

index_list = []
for i in range(0, df.shape[0]):
    index_list.append('item_'+str(i))

# %%
df['index'] = ['item_' + str(i) for i in range(df_c0, df.shape[0])]

# %%
df = df.set_index('index')

# %%
df.loc[['item_1']]
# Out:
#         col                 col2
# index
# item_1    2  2015-01-02 00:00:00

# %%
df.iloc[1]
# Out:
# col                       2
# col2    2015-01-02 00:00:00
# Name: item_1, dtype: object

# %%
df_concat = pd.concat([df, df_new])
df_concat
# Out:
#    col       col2
# 0    1 2015-01-01
# 1    2 2015-01-02
# 2    3 2015-01-03
# 3    4 2015-01-04
# 0    5 2015-01-01
# 1    6 2015-01-02
# 2    7 2015-01-03
# 3    8 2015-01-04

# %%
df_concat.loc[3]
# Out:
#    col       col2
# 3    4 2015-01-04
# 3    8 2015-01-04

# %%
df_concat.loc[3].iloc[0]
# Out:
# col                       4
# col2    2015-01-04 00:00:00
# Name: 3, dtype: object

# %%
df_concat.sort_values('col', ascending=False, inplace=True)

# %%
A = [1,2,5,4]

# %%
B = A

# %%
B[1] = 6

# %%
B
# Out:
# [1, 6, 4, 5]

# %%
A = [1,2,5,4]
B = sorted(A)
A, B
# Out:
# ([1, 2, 5, 4], [1, 2, 4, 5])

# %%
A.append(6)

# %%
A + B
# Out:
# [1, 2, 5, 4, 6, 1, 2, 4, 5]

# %%
df[['col', 'col2']]
# Out:
#    col       col2
# 0    1 2015-01-01
# 1    2 2015-01-02
# 2    3 2015-01-03
# 3    4 2015-01-04

# %%
df.columns = ['col3', 'col4']

# %%
df = df.rename(columns={'col3': 'col_liczba'})
df
# Out:
#    col_liczba       col4
# 0           1 2015-01-01
# 1           2 2015-01-02
# 2           3 2015-01-03
# 3           4 2015-01-04

# %%
df.rename({0: 'row_liczba'})
# Out:
#             col_liczba       col4
# row_liczba           1 2015-01-01
# 1                    2 2015-01-02
# 2                    3 2015-01-03
# 3                    4 2015-01-04

# %%
df[df.columns[df.dtypes=='int64']]
# Out:
#    col_liczba
# 0           1
# 1           2
# 2           3
# 3           4

# %%
df.select_dtypes(include='int64')
# Out:
#    col_liczba
# 0           1
# 1           2
# 2           3
# 3           4

# %%
df[[True, False, True, False]]
# Out:
#    col_liczba       col4
# 0           1 2015-01-01
# 2           3 2015-01-03

# %%
df[df.col_liczba > 2]
# Out:
#    col_liczba       col4
# 2           3 2015-01-03
# 3           4 2015-01-04

# %%
df.query("col_liczba > 2")
# Out:
#    col_liczba       col4
# 2           3 2015-01-03
# 3           4 2015-01-04

# %%
df[(df.col_liczba > 2) | (df.col4 < '2015-01-04') ]
# Out:
#    col_liczba       col4
# 0           1 2015-01-01
# 1           2 2015-01-02
# 2           3 2015-01-03
# 3           4 2015-01-04

# %%
df['gr'] = ['a', 'b'] * 2

# %%
for df_gr in df.groupby('gr'):
    print(df_gr)
# Out:
# ('a',    col_liczba       col4 gr
# 0           1 2015-01-01  a
# 2           3 2015-01-03  a)
# ('b',    col_liczba       col4 gr
# 1           2 2015-01-02  b
# 3           4 2015-01-04  b)

# %%
df.groupby('gr').agg( 'mean')
# Out:
#     col_liczba       col4
# gr
# a          2.0 2015-01-02
# b          3.0 2015-01-03

# %%
df.groupby('gr').agg({'col_liczba': ['sum', 'mean']})
# Out:
#    col_liczba
#           sum mean
# gr
# a           4  2.0
# b           6  3.0

# %%
df.groupby('gr').agg(col_liczba_sum = ('col_liczba', 'sum'), 
                     col_liczba_mean = ('col_liczba', 'mean'), )
# Out:
#     col_liczba_sum  col_liczba_mean
# gr
# a                4              2.0
# b                6              3.0

# %%
for idx, data in df.iterrows():
    # print(idx, data.col_liczba, data.col4)
    df.loc[idx, 'col_liczba'] = data.col_liczba + 2

# %%
df
# Out:
#    col_liczba       col4 gr
# 0           5 2015-01-01  a
# 1           6 2015-01-02  b
# 2           7 2015-01-03  a
# 3           8 2015-01-04  b

# %%
df.apply(lambda x: str(x.col_liczba) + x.gr , axis=1 )
# Out:
# 0    5a
# 1    6b
# 2    7a
# 3    8b
# dtype: object

# %%
import seaborn as sns
df_pingwinki = sns.load_dataset('penguins')

# %% [markdown]
# Zadanie:
#
# 1. Jaka jest srednia waga pingwinkow wg plci i gatunku? (uwzglednij tez NaN w plci)
#
# 2. zamien wyspe na zmienna Kategoryczna. Pogrupuj dane po wyspie (zmiennej kategorycznej) oraz gatunku i oblicz:
#     * liczbe pingwinow w danej grupie
#     * srednia waga pingwinkow w danej grupie
#     * liczbe pingwinow danej plci w danej grupie - przy uzyciu funkcji lambda.
#
# Przetestuj jak dziala parametr `observed` w `groupby` przy zmiennej kategorycznej.

# %%
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...
