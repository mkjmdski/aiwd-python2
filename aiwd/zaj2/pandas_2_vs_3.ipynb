# %%
import pandas as pd

# %% [markdown]
# obecnie najnowsza stabilna wersja pandasa jest 2.3. Wkrotce pojawi sie pandas 3.0 (narazie jest w wersji dev)
# kozystajac z pliku requiraments_p3.txt mozemy stworzyc dodatkowe srodowisko z zainstalowana dev wersja padanas 3.0 i porownac dzialanie z pandasem 2.3
#
# Przypomnienie:
# * aby stworzyc nowe srodowisko uzywamy polecenia:
#     ```
#     python -m venv <root katalogu projektu>/nazwasrodowiska
#     ```
# * aby aktywowac srodowisko:
#     - na Windows:
#             ```
#             <root katalogu projektu>\nazwasrodowiska\Scripts\activate.<bat/ps1>
#             ```
#     - na macOS/Linux:
#             ```
#             source <root katalogu projektu>/nazwasrodowiska/bin/activate
#             ```
#
# * aby zainstalowac pakiety z pliku requirements.txt uzywamy polecenia:
#     ```
#     pip install -r requirements.txt
#     ```
#
# Aby wybrac srodowisko w VSCode, naciskamy `Cmd+Shift+P` (macOS) lub `Ctrl+Shift+P` (Windows/Linux) i wybieramy `Python: Select Interpreter`, a nastepnie wybieramy srodowisko, ktore wlasnie stworzylysmy. LUB w prawym gornym rogu okna VSCode klikamy na nazwe aktualnie wybranego interpretera Pythona (lub **Select Kernel** ) i wybieramy srodowisko, ktore wlasnie stworzylysmy.

# %% [markdown]
# aby sprawdzic wersje pandasa:
# `pd.__version__`

# %%
pd.__version__ 
## zwraca 2.3.3 dla aiw_py3.13

## zwraca '3.0.0rc0' dla srodowiska venv_pandas3
# Out:
# '3.0.0rc0'

# %%
# tworzenie DataFrame z listy 2-wymiarowej. Kazdy wiersz to wiersz w DataFrame.
data = [[1,'a'],
[2, 'b'],
[3, 'c']]

df = pd.DataFrame(data)
display(df)

# pandas domyslnie nadaje indeks i nazwy kolumn
# mozemy rowniez podac kolumni lub indeks w parametrach:

df = pd.DataFrame(data, columns=['id', 'nazwa'])
display(df)

df = pd.DataFrame(data, columns=['id', 'nazwa'], index=['A1', 'A2', 'A3'])
display(df)
# Out:
#    0  1
# 0  1  a
# 1  2  b
# 2  3  c
#    id nazwa
# 0   1     a
# 1   2     b
# 2   3     c
#     id nazwa
# A1   1     a
# A2   2     b
# A3   3     c

# %%
## pandas automatycznie dobiera typy danych: 
df.info()

## ------------------------------------------------------------------
## Rezultat dla pandas 2.3:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, A1 to A3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype 
# ---  ------  --------------  ----- 
#  0   id      3 non-null      int64 
#  1   nazwa   3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 72.0+ bytes

## ------------------------------------------------------------------
## Rezultat dla pandas 3.0
# <class 'pandas.DataFrame'>
# Index: 3 entries, A1 to A3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   nazwa   3 non-null      str  
# dtypes: int64(1), str(1)
# memory usage: 72.0+ bytes

## ------------------------------------------------------------------
# ROZNICE:
# - kolumna nazwa w pandas 2.3 ma typ object, a w 3.0 typ 'str'
# Out:
# <class 'pandas.DataFrame'>
# Index: 3 entries, A1 to A3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   nazwa   3 non-null      str
# dtypes: int64(1), str(1)
# memory usage: 72.0+ bytes

# %%
## konsekwencje zmiany typu:

# ponizsza komenda zmienia wartosc dla "nazwa" w wierszu "A3" dataFrame: w pandas3.0 zwroci blad
# "TypeError: Invalid value '5' for dtype 'str'. Value should be a string or missing value, got 'int' instead."
# ale zadziala dla pandas2.3

df.loc['A3'] = [4, 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       1 ## konsekwencje zmiany typu:
#       2
#       3 # ponizsza komenda zmienia wartosc dla "nazwa" w wierszu "A3" dataFrame: w pandas3.0 zwroci blad
#       4 # "TypeError: Invalid value '5' for dtype 'str'. Value should be a string or missing value, got 'int' instead."
#       5 # ale zadziala dla pandas2.3
# ----> 7 df.loc['A3'] = [4, 5]
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
#    1952     # We have to operate column-wise
# -> 1953     self._setitem_with_indexer_split_path(indexer, value, name)
#    1954 else:
#    1955     self._setitem_single_block(indexer, value, name)
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/indexing.py:2026, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    2023 elif len(ilocs) == len(value):
#    2024     # We are setting multiple columns in a single row.
#    2025     for loc, v in zip(ilocs, value, strict=True):
# -> 2026         self._setitem_single_column(loc, v, pi)
#    2028 elif len(ilocs) == 1 and com.is_null_slice(pi) and len(self.obj) == 0:
#    2029     # This is a setitem-with-expansion, see
#    2030     #  test_loc_setitem_empty_append_expands_rows_mixed_dtype
#    2031     # e.g. df = DataFrame(columns=["x", "y"])
#    2032     #  df["x"] = df["x"].astype(np.int64)
#    2033     #  df.loc[:, "x"] = [1, 2, 3]
#    2034     self._setitem_single_column(ilocs[0], value, pi)
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/indexing.py:2181, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2171 if dtype == np.void:
#    2172     # This means we're expanding, with multiple columns, e.g.
#    2173     #     df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
#    (...)   2176     # Here, we replace those temporary `np.void` columns with
#    2177     # columns of the appropriate dtype, based on `value`.
#    2178     self.obj.iloc[:, loc] = construct_1d_array_from_inferred_fill_value(
#    2179         value, len(self.obj)
#    2180     )
# -> 2181 self.obj._mgr.column_setitem(loc, plane_indexer, value)
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/internals/managers.py:1493, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1491     col_mgr.setitem_inplace(idx, value)
#    1492 else:
# -> 1493     new_mgr = col_mgr.setitem((idx,), value)
#    1494     self.iset(loc, new_mgr._block.values, inplace=True)
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/internals/managers.py:603, in BaseBlockManager.setitem(self, indexer, value)
#     599     # No need to split if we either set all columns or on a single block
#     600     # manager
#     601     self = self.copy(deep=True)
# --> 603 return self.apply("setitem", indexer=indexer, value=value)
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/internals/managers.py:441, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     439         applied = b.apply(f, **kwargs)
#     440     else:
# --> 441         applied = getattr(b, f)(**kwargs)
#     442     result_blocks = extend_blocks(applied, result_blocks)
#     444 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/internals/blocks.py:1667, in EABackedBlock.setitem(self, indexer, value)
#    1664 check_setitem_lengths(indexer, value, values)
#    1666 try:
# -> 1667     values[indexer] = value
#    1668 except (ValueError, TypeError):
#    1669     if isinstance(self.dtype, IntervalDtype):
#    1670         # see TestSetitemFloatIntervalWithIntIntervalValues
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/arrays/string_.py:807, in StringArray.__setitem__(self, key, value)
#     804 if self._readonly:
#     805     raise ValueError("Cannot modify read-only array")
# --> 807 value = self._maybe_convert_setitem_value(value)
#     809 key = check_array_indexer(self, key)
#     810 scalar_key = lib.is_scalar(key)
#
# File ~/projects/UAM_DS/venv_pandas3/lib/python3.13/site-packages/pandas/core/arrays/string_.py:781, in StringArray._maybe_convert_setitem_value(self, value)
#     779         value = self.dtype.na_value
#     780     elif not isinstance(value, str):
# --> 781         raise TypeError(
#     782             f"Invalid value '{value}' for dtype '{self.dtype}'. Value should "
#     783             f"be a string or missing value, got '{type(value).__name__}' "
#     784             "instead."
#     785         )
#     786 else:
#     787     value = extract_array(value, extract_numpy=True)
#
# TypeError: Invalid value '5' for dtype 'str'. Value should be a string or missing value, got 'int' instead.

# %%
# jezeli sprobujemy dodac analogiczny wiersz w pandas3.0 kolumna nazwa zmienie typ ze string na object
print("typ PRZED dodaniem wiesza: ")
print(df.info())

df.loc['A4'] = [4, 5] 
print("-----------------------------------------")
print("typ PO dodaniem wiesza: ")
print(df.info())
# Out:
# typ PRZED dodaniem wiesza:
# <class 'pandas.DataFrame'>
# Index: 4 entries, A1 to A4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      int64
#  1   nazwa   4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 96.0+ bytes
# None
# -----------------------------------------
# typ PO dodaniem wiesza:
# <class 'pandas.DataFrame'>
# Index: 4 entries, A1 to A4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      int64
#  1   nazwa   4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 268.0+ bytes
# None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, A1 to A3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   nazwa   3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes
