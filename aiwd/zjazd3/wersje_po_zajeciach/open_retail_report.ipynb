# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import display, Markdown

# %%
df = pd.read_excel("J:\AnalizaPython\zjazd3\Online_retail\Online Retail.xlsx")

# %%
df['CustomerID'] = df['CustomerID'].astype('Int64')
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

# %% [markdown]
# # EDA
#
# ## Quantity analysis

# %%
display(Markdown(f"Liczba rekordow z brakujaca wartoscia (nan) {df.Quantity.isna().sum()}"))
display(Markdown(f"Liczba rekordow z wartoscia zerowa {df.query("Quantity==0").shape[0]}"))

# %%
df['Invoice_First_char'] = df.InvoiceNo.str[0]
df.query("Quantity < 0").Invoice_First_char.value_counts()

df.query("Quantity < 0 and Invoice_First_char == '5'")['CustomerID'].unique()

display(Markdown("Faktury z ujemna wartosc quantity maja nastepujaca struktue InvoiceNo: "))
display(df.query("Quantity < 0").Invoice_First_char.value_counts())
